# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ##### **Kiran Kumar**
# ##### Desired Occupation - Data Scientist

# %% [markdown]
# ###### *I am interested in data science because I want to create solutions for the problems faced by humanity through data analysis*

# %% [markdown]
# ### Code in the below cell prints Hello IBM

# %%
print("Hello IBM")
# Out:
# Hello IBM

# %% [markdown]
# ### Example for Bullet List
# - Hello
# - IBM
# - Coursera

# %% [markdown]
# ### Example for Numbered List
# 1. Hello
# 2. IBM
# 3. Coursera

# %% [markdown]
# ### Example for Hyperlink
# https://www.google.com/   # link to Google

# %% [markdown]
# ### Example for Strikethrough
# ~~Not to use~~

# %% [markdown]
# ### Example for Blocked Quites
# > This email is of very high priority. Hence, reply at the earliest
# > Thanks! Have a good rest of the day.
